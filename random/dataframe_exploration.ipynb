# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\nancy\OneDrive\Desktop\SPoC\data\train\split\spoc-train-test.tsv', sep='\t')

# %%
df[df.subid == 48515762]
# Out:
#                                                  text  \
# 0                                                 NaN
# 1                                    create integer n
# 2                                              read n
# 3      create integers cur, cnt with cur = 1, cnt = 0
# 4                           create integer vector ans
# 5                            for i = 0 to n exclusive
# 6                                    create integer x
# 7                                              read x
# 8                                         if x is cur
# 9                                       increment cnt
# 10                                      increment cur
# 11                                               else
# 12                      add element cnt to end of ans
# 13                                       set cnt to 1
# 14                                       set cur to 2
# 15                                                NaN
# ...

# %%
unique_subids = df.subid.unique()

# %%
df[df.subid == 42115319]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df[df.subid == 42115319]
#
# NameError: name 'df' is not defined

# %%
print(len(unique_subids))
# Out:
# 1019
